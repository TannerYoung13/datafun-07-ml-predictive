# %%
# carddataclass.py
"""Card data class with class attributes, data attributes,
autogenerated methods and explicitly defined methods."""
from dataclasses import dataclass
from typing import ClassVar, List

@dataclass
class Card:
    FACES: ClassVar[List[str]] = ['Ace', '2', '3', '4', '5', '6', '7', 
                                  '8', '9', '10', 'Jack', 'Queen', 'King']
    SUITS: ClassVar[List[str]] = ['Hearts', 'Diamonds', 'Clubs', 'Spades']

    face: str
    suit: str

    @property
    def image_name(self):
        """Return the Card's image file name."""
        return str(self).replace(' ', '_') + '.png'

    def __str__(self):
        """Return string representation for str()."""
        return f'{self.face} of {self.suit}'
    
    def __format__(self, format):
        """Return formatted string representation."""
        return f'{str(self):{format}}'

# %%
# carddataclass.py
"""Card data class with class attributes, data attributes, 
autogenerated methods and explicitly defined methods."""
from dataclasses import dataclass
from typing import ClassVar, List

# %%
@dataclass
class Card:
    FACES: ClassVar[List[str]] = ['Ace', '2', '3', '4', '5', '6', '7', 
                                  '8', '9', '10', 'Jack', 'Queen', 'King']
    SUITS: ClassVar[List[str]] = ['Hearts', 'Diamonds', 'Clubs', 'Spades']

# %% [markdown]
# # 10.13.2

# %%
from carddataclass import Card
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\ksu09\Intro to Python\datafun-07-ml-predictive\10.13.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ksu09/Intro%20to%20Python/datafun-07-ml-predictive/10.13.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> from carddataclass import Card
#
# ImportError: cannot import name 'Card' from 'carddataclass' (c:\Users\ksu09\Intro to Python\datafun-07-ml-predictive\carddataclass.py)

# %%
c1 = Card(Card.FACES[0], Card.SUITS[3])

# %%
c1
# Out:
# Card(face='Ace', suit='Spades')

# %%
print(c1)
# Out:
# Ace of Spades

# %%
c1.face
# Out:
# 'Ace'

# %%
c1.suit
# Out:
# 'Spades'

# %%
c1.image_name
# Out:
# 'Ace_of_Spades.png'

# %%
c2 = Card(Card.FACES[0], Card.SUITS[3])

# %%
c2
# Out:
# Card(face='Ace', suit='Spades')

# %%
c3 = Card(Card.FACES[0], Card.SUITS[0])

# %%
c3
# Out:
# Card(face='Ace', suit='Hearts')

# %%
c1 == c2
# Out:
# True

# %%
c1 == c3
# Out:
# False

# %%
c1 != c3
# Out:
# True

# %%
from deck2 import DeckOfCards  # uses Card data class
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\ksu09\Intro to Python\datafun-07-ml-predictive\10.13.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ksu09/Intro%20to%20Python/datafun-07-ml-predictive/10.13.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> from deck2 import DeckOfCards  # uses Card data class
#
# ImportError: cannot import name 'DeckOfCards' from 'deck2' (c:\Users\ksu09\Intro to Python\datafun-07-ml-predictive\deck2.py)

# %%
deck_of_cards = DeckOfCards()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ksu09\Intro to Python\datafun-07-ml-predictive\10.13.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ksu09/Intro%20to%20Python/datafun-07-ml-predictive/10.13.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> deck_of_cards = DeckOfCards()
#
# NameError: name 'DeckOfCards' is not defined

# %%
print(deck_of_cards)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ksu09\Intro to Python\datafun-07-ml-predictive\10.13.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ksu09/Intro%20to%20Python/datafun-07-ml-predictive/10.13.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> print(deck_of_cards)
#
# NameError: name 'deck_of_cards' is not defined
